# %%
import numpy as np
from scipy.io import loadmat
import scipy
from scipy.sparse import linalg
import matplotlib.pyplot as plt
from decimal import Decimal
import time
import matplotlib.pyplot as plt

# %% [markdown]
# # Image reconstruction in X-ray tomography

# %% [markdown]
# $\underline{\textbf{Q1.}}$ We start by loading the matrix $H$ and the image matrix $\bar{x}$

# %%
x = loadmat("data/x.mat")['x']
H = loadmat("data/H.mat")['H']
G = loadmat("data/H.mat")['H']

# %% [markdown]
# Let's visualize the image $\bar{x}$

# %%
plt.imshow(x.reshape(90,90).T,cmap = 'gray')

# %%
M = H.shape[0]
N = x.shape[0]

sigma = 1
lamb = 0.13
delta = 0.02

w = np.random.normal(scale = sigma, size=(M,1))
y = H*x+w

# %%
plt.imshow(y.reshape(180,90).T,cmap = 'gray')

# %%
def grad_f(x,y,G,H,lamb,delta):
    return H.T*(H*x - y) + lamb * r_prime(x,delta,G)

def psi_prime(u,delta):
    return 1/(delta**2 * psi(u,delta))

def psi(u,delta):
    return np.sqrt(1+u**2/delta**2)

def f(x,y,G,H,lamb,delta):
    return 0.5*np.linalg.norm(H*x - y)**2 + lamb*r(x,delta,G) 

def A(x,y,G,H,lamb,delta):
    return H.T*H + lamb/delta**2*G.T*G # To compute

def r(x,delta,G):
    return float(np.sum(psi(G*x,delta),axis=0))

def r_prime(x,delta,G):
    return np.sum(G.T*psi_prime(G*x,delta),axis=1).reshape(N,1)

def SNR(x_hat,x):
    return 10 * np.log10(np.linalg.norm(x)**2/np.linalg.norm(x-x_hat)**2)

x0 = np.zeros((N,1))
L = scipy.sparse.linalg.norm(H)**2 + delta/lamb**2 * scipy.sparse.linalg.norm(G)**2
A0 = A(x,y,G,H,lamb,delta)

# %%
print(H.shape)
print(G.shape)
print(N)
# Out:
# (16200, 8100)
# (16200, 8100)
# 8100

# %%
def gradient_descent(f,grad_f,x0,L,N,y,G,H,lamb,delta):
    gamma = 1/L
    grad = N*1e-4
    x = x0
    it = 0
    itermax = 100
    #criterion = f(x,y,G,H,lamb,delta)
    #print("Iteration 0, objective: {:.2E}".format(Decimal(criterion)))
    objectives = []
    times = [0]
    
    while grad > np.sqrt(N)*1e-4 and it < itermax: 
        it += 1
        t1 = time.time()
        gradient = grad_f(x,y,G,H,lamb,delta)
        x = x - 50*gamma*gradient
        grad = np.linalg.norm(gradient)
        criterion = f(x,y,G,H,lamb,delta)        
        objectives.append(criterion)
        
        if it%10 == 0:
            print("Iteration {}, objective: {:.2E},{}".format(it,Decimal(criterion),lamb*r(x,delta,G) ))        
        t2 = time.time()
        times.append(times[-1]+t2-t1)
    return x,objectives,times
        
x_hat,objectives,times = gradient_descent(f,grad_f,x0,L,N,y,G,H,0.01,delta)
plt.figure()
plt.semilogy(times[1:],objectives)
plt.grid(which='both')
print('\nSignal to Noise Ratio:',SNR(x_hat,x))
plt.figure()
plt.imshow(x_hat.reshape(90,90).T,cmap = 'gray')
# Out:
# Iteration 10, objective: 2.98E+5,211612.83062902652
# Iteration 20, objective: 2.51E+5,210513.75509300083
# Iteration 30, objective: 2.36E+5,209708.26559855745
# Iteration 40, objective: 2.29E+5,209248.4194605934
# Iteration 50, objective: 2.26E+5,208944.63454121083
# Iteration 60, objective: 2.24E+5,209043.53098928998
# Iteration 70, objective: 2.22E+5,209167.95575956788
# Iteration 80, objective: 2.21E+5,209314.1554937768
# Iteration 90, objective: 2.20E+5,209408.3608029723
# Iteration 100, objective: 2.20E+5,209474.55469145175
#
# Signal to Noise Ratio: 16.240731385561876

# %%
def MM_quadratic(f,grad_f,A0,x0,L,N,y,G,H,lamb,delta):
    gamma = 1/L
    grad = N*1e-4
    x = x0
    it = 0
    itermax = 100
    #criterion = f(x,y,G,H,lamb,delta)
    #print("Iteration 0, objective: {:.2E}".format(Decimal(criterion)))
    objectives = []
    times = [0]
    
    while grad > np.sqrt(N)*1e-4 and it < itermax: 
        it += 1
        t1 = time.time()
        gradient = grad_f(x,y,G,H,lamb,delta)
        x = x - scipy.sparse.linalg.spsolve(A0,gradient)
        grad = np.linalg.norm(gradient)
        criterion = f(x,y,G,H,lamb,delta)        
        objectives.append(criterion)
        
        if it%1 == 0:
            print("Iteration {}, objective: {:.2E}".format(it,Decimal(criterion)))        
        t2 = time.time()
        times.append(times[-1]+t2-t1)
    return x,objectives,times
        
x_hat,objectives,times = MM_quadratic(f,grad_f,A0,x0,L,N,y,G,H,lamb,delta)
plt.figure()
plt.semilogy(times[1:],objectives)
plt.grid(which='both')
print('\nSignal to Noise Ratio:',SNR(x_hat,x))
plt.figure()
plt.imshow(x_hat.reshape(90,90).T,cmap = 'gray')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-d450f514fa81> in <module>
#      25     return x,objectives,times
#      26
# ---> 27 x_hat,objectives,times = MM_quadratic(f,grad_f,A0,x0,L,N,y,G,H,lamb,delta)
#      28 plt.figure()
#      29 plt.semilogy(times[1:],objectives)
#
# <ipython-input-14-d450f514fa81> in MM_quadratic(f, grad_f, A0, x0, L, N, y, G, H, lamb, delta)
#      16         x = x - scipy.sparse.linalg.spsolve(A0,gradient)
#      17         grad = np.linalg.norm(gradient)
# ---> 18         criterion = f(x,y,G,H,lamb,delta)
#      19         objectives.append(criterion)
#      20
#
# <ipython-input-13-a61f97cc688c> in f(x, y, G, H, lamb, delta)
#       9
#      10 def f(x,y,G,H,lamb,delta):
# ---> 11     return 0.5*np.linalg.norm(H*x - y)**2 + lamb*r(x,delta,G)
#      12
#      13 def A(x,y,G,H,lamb,delta):
#
# ~/.local/lib/python3.6/site-packages/scipy/sparse/base.py in __mul__(self, other)
#     471                 return self._mul_vector(other.ravel()).reshape(M, 1)
#     472             elif other.ndim == 2 and other.shape[0] == N:
# --> 473                 return self._mul_multivector(other)
#     474
#     475         if isscalarlike(other):
#
# ~/.local/lib/python3.6/site-packages/scipy/sparse/compressed.py in _mul_multivector(self, other)
#     480         fn = getattr(_sparsetools, self.format + '_matvecs')
#     481         fn(M, N, n_vecs, self.indptr, self.indices, self.data,
# --> 482            other.ravel(), result.ravel())
#     483
#     484         return result
#
# KeyboardInterrupt:

# %%
def MG(f,grad_f,A0,x0,L,N,y,G,H,lamb,delta):
    gamma = 1/L
    grad = N*1e-4
    x = x0
    it = 0
    itermax = 100
    #criterion = f(x,y,G,H,lamb,delta)
    #print("Iteration 0, objective: {:.2E}".format(Decimal(criterion)))
    objectives = []
    times = [0]
    
    while grad > np.sqrt(N)*1e-4 and it < itermax: 
        it += 1
        t1 = time.time()
        gradient = grad_f(x,y,G,H,lamb,delta)
        D = np.concatenate(-gradient,diff)
        u = - scipy.sparse.linalg.spsolve(D.T*A0*D,D*gradient)
        x = x + D*u
        grad = np.linalg.norm(gradient)
        criterion = f(x,y,G,H,lamb,delta)        
        objectives.append(criterion)
        
        if it%10 == 0:
            print("Iteration {}, objective: {:.2E}".format(it,Decimal(criterion)))        
        t2 = time.time()
        times.append(times[-1]+t2-t1)
        diff = D*u
    return x,objectives,times
        
x_hat,objectives,times = MG(f,grad_f,A,x0,L,N,y,G,H,lamb,delta)
plt.figure()
plt.semilogy(times[1:],objectives)
plt.grid(which='both')
print('\nSignal to Noise Ratio:',SNR(x_hat,x))
plt.figure()
plt.imshow(x_hat.reshape(90,90).T,cmap = 'gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-fb8fc708f305> in <module>
#      28     return x,objectives,times
#      29
# ---> 30 x_hat,objectives,times = MM_quadratic(f,grad_f,A,x0,L,N,y,G,H,lamb,delta)
#      31 plt.figure()
#      32 plt.semilogy(times[1:],objectives)
#
# <ipython-input-110-927a3169a10e> in MM_quadratic(f, grad_f, A, x0, L, N, y, G, H, lamb, delta)
#      14         t1 = time.time()
#      15         gradient = grad_f(x,y,G,H,lamb,delta)
# ---> 16         x = x - scipy.sparse.linalg.spsolve(A(x,y,G,H,lamb,delta),gradient)
#      17         grad = np.linalg.norm(gradient)
#      18         criterion = f(x,y,G,H,lamb,delta)
#
# ~/.local/lib/python3.6/site-packages/scipy/sparse/linalg/dsolve/linsolve.py in spsolve(A, b, permc_spec, use_umfpack)
#     141     # sum duplicates for non-canonical format
#     142     A.sum_duplicates()
# --> 143     A = A.asfptype()  # upcast to a floating point format
#     144     result_dtype = np.promote_types(A.dtype, b.dtype)
#     145     if A.dtype != result_dtype:
#
# ~/.local/lib/python3.6/site-packages/scipy/sparse/base.py in asfptype(self)
#     203
#     204             raise TypeError('cannot upcast [%s] to a floating '
# --> 205                             'point format' % self.dtype.name)
#     206
#     207     def __iter__(self):
#
# TypeError: cannot upcast [object] to a floating point format
