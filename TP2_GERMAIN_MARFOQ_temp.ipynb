# %% [markdown]
# # Reconstruction of DOSY NMR signals - Part I

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import random

# %% [markdown]
# ## 1) Generation of synthetic data

# %% [markdown]
# $\underline{\textbf{Q1.}}$ Let's read the signal data from the file "signal.dat"

# %%
N = 200
signal = np.zeros(N)

filepath = 'signal.txt'  
with open(filepath) as fp:  
    line = fp.readline()
    cnt = 1
    while line:
        signal[cnt-1] = np.float64(line)
        line = fp.readline()
        cnt += 1
    
signal
# Out:
# array([2.0440461e-15, 9.5346375e-15, 4.2731280e-14, 1.8399916e-13,
#        7.6122670e-13, 3.0258013e-12, 1.1555667e-11, 4.2401169e-11,
#        1.4948199e-10, 5.0632357e-10, 1.6477664e-09, 5.1521838e-09,
#        1.5478015e-08, 4.4675295e-08, 1.2389329e-07, 3.3010826e-07,
#        8.4507101e-07, 2.0785393e-06, 4.9119223e-06, 1.1152519e-05,
#        2.4328910e-05, 5.0991828e-05, 1.0268493e-04, 1.9867402e-04,
#        3.6932070e-04, 6.5962097e-04, 1.1319141e-03, 1.8662109e-03,
#        2.9562161e-03, 4.4992472e-03, 6.5791799e-03, 9.2434029e-03,
#        1.2477289e-02, 1.6182171e-02, 2.0164227e-02, 2.4140963e-02,
#        2.7768717e-02, 3.0689178e-02, 3.2586891e-02, 3.3245190e-02,
#        3.2586892e-02, 3.0689180e-02, 2.7768719e-02, 2.4140966e-02,
#        2.0164233e-02, 1.6182182e-02, 1.2477307e-02, 9.2434342e-03,
#        6.5792322e-03, 4.4993339e-03, 2.9563583e-03, 1.8664419e-03,
#        1.1322857e-03, 6.6021251e-04, 3.7025309e-04, 2.0012899e-04,
#        1.0493282e-04, 5.4430173e-05, 2.9535840e-05, 1.8959282e-05,
#        1.6500158e-05, 1.9108777e-05, 2.5623920e-05, 3.6024388e-05,
#        5.1030384e-05, 7.1924127e-05, 1.0049867e-04, 1.3907696e-04,
#        1.9056609e-04, 2.5852500e-04, 3.4723121e-04, 4.6173472e-04,
#        6.0788788e-04, 7.9233987e-04, 1.0224842e-03, 1.3063476e-03,
#        1.6524105e-03, 2.0693512e-03, 2.5657098e-03, 3.1494730e-03,
#        3.8275892e-03, 4.6054259e-03, 5.4861962e-03, 6.4703820e-03,
#        7.5551931e-03, 8.7341022e-03, 9.9965012e-03, 1.1327520e-02,
#        1.2708044e-02, 1.4114959e-02, 1.5521640e-02, 1.6898674e-02,
#        1.8214813e-02, 1.9438102e-02, 2.0537144e-02, 2.1482425e-02,
#        2.2247623e-02, 2.2810824e-02, 2.3155565e-02, 2.3271633e-02,
#        2.3155565e-02, 2.2810824e-02, 2.2247623e-02, 2.1482425e-02,
#        2.0537144e-02, 1.9438102e-02, 1.8214813e-02, 1.6898674e-02,
#        1.5521640e-02, 1.4114959e-02, 1.2708044e-02, 1.1327520e-02,
#        9.9965012e-03, 8.7341022e-03, 7.5551931e-03, 6.4703820e-03,
#        5.4861962e-03, 4.6054259e-03, 3.8275892e-03, 3.1494730e-03,
#        2.5657098e-03, 2.0693512e-03, 1.6524105e-03, 1.3063476e-03,
#        1.0224842e-03, 7.9233987e-04, 6.0788786e-04, 4.6173468e-04,
#        3.4723106e-04, 2.5852449e-04, 1.9056444e-04, 1.3907181e-04,
#        1.0048319e-04, 7.1879451e-05, 5.0906491e-05, 3.5694279e-05,
#        2.4778849e-05, 1.7030237e-05, 1.1588236e-05, 7.8067632e-06,
#        5.2069300e-06, 3.4383456e-06, 2.2478865e-06, 1.4549775e-06,
#        9.3238490e-07, 5.9154970e-07, 3.7157314e-07, 2.3107578e-07,
#        1.4227271e-07, 8.6725305e-08, 5.2339205e-08, 3.1272706e-08,
#        1.8499537e-08, 1.0834611e-08, 6.2823600e-09, 3.6065286e-09,
#        2.0498071e-09, 1.1534365e-09, 6.4258621e-10, 3.5442650e-10,
#        1.9354325e-10, 1.0463739e-10, 5.6008361e-11, 2.9680818e-11,
#        1.5572414e-11, 8.0889666e-12, 4.1599414e-12, 2.1180609e-12,
#        1.0676938e-12, 5.3285869e-13, 2.6329005e-13, 1.2879941e-13,
#        6.2380721e-14, 2.9911896e-14, 1.4200203e-14, 6.6742462e-15,
#        3.1057532e-15, 1.4308322e-15, 6.5263078e-16, 2.9471581e-16,
#        1.3176388e-16, 5.8323876e-17, 2.5559563e-17, 1.1089642e-17,
#        4.7636375e-18, 2.0258949e-18, 8.5300621e-19, 3.5558589e-19,
#        1.4675534e-19, 5.9965346e-20, 2.4258494e-20, 9.7159302e-21,
#        3.8526716e-21, 1.5125044e-21, 5.8787956e-22, 2.2622320e-22,
#        8.6187237e-23, 3.2509167e-23, 1.2140198e-23, 4.4885159e-24])

# %% [markdown]
# $\underline{\textbf{Q2.}}$  We create first T using an exponential sampling strategy:

# %%
T_min = 1 
T_max = 1000
T = np.array([T_min*np.exp(-n*(np.log(T_min/T_max))/(N-1)) for n in range(N)],dtype=np.float64)
T
# Out:
# array([   1.        ,    1.03532184,    1.07189132,    1.1097525 ,
#           1.148951  ,    1.18953407,    1.2315506 ,    1.27505124,
#           1.3200884 ,    1.36671636,    1.4149913 ,    1.4649714 ,
#           1.51671689,    1.57029012,    1.62575567,    1.68318035,
#           1.74263339,    1.80418641,    1.8679136 ,    1.93389175,
#           2.00220037,    2.07292178,    2.1461412 ,    2.22194686,
#           2.30043012,    2.38168555,    2.46581108,    2.55290807,
#           2.64308149,    2.73644   ,    2.8330961 ,    2.93316628,
#           3.03677112,    3.14403547,    3.2550886 ,    3.37006433,
#           3.48910121,    3.6123427 ,    3.7399373 ,    3.87203878,
#           4.00880633,    4.15040476,    4.2970047 ,    4.44878283,
#           4.60592204,    4.7686117 ,    4.93704785,    5.11143348,
#           5.29197874,    5.47890118,    5.67242607,    5.87278661,
#           6.08022426,    6.29498899,    6.5173396 ,    6.74754405,
#           6.98587975,    7.2326339 ,    7.48810386,    7.75259749,
#           8.02643352,    8.30994195,    8.60346442,    8.90735464,
#           9.22197882,    9.54771611,    9.88495905,   10.23411402,
#          10.59560179,   10.96985798,   11.35733358,   11.75849554,
#          12.17382728,   12.6038293 ,   13.04901978,   13.50993521,
#          13.98713103,   14.48118228,   14.99268433,   15.52225357,
#          16.07052818,   16.63816886,   17.22585965,   17.83430877,
#          18.46424943,   19.11644075,   19.79166868,   20.4907469 ,
#          21.21451785,   21.96385372,   22.73965752,   23.54286414,
#          24.3744415 ,   25.2353917 ,   26.12675226,   27.0495973 ,
#          28.00503894,   28.99422854,   30.01835814,   31.07866188,
#          32.1764175 ,   33.31294788,   34.4896226 ,   35.70785965,
#          36.96912707,   38.27494479,   39.62688639,   41.02658106,
#          42.47571553,   43.97603609,   45.52935075,   47.13753134,
#          48.80251584,   50.52631065,   52.31099308,   54.15871378,
#          56.07169938,   58.05225516,   60.10276782,   62.22570837,
#          64.42363509,   66.69919663,   69.0551352 ,   71.49428987,
#          74.01959997,   76.63410868,   79.34096666,   82.14343585,
#          85.04489342,   88.04883582,   91.158883  ,   94.37878278,
#          97.71241535,  101.16379798,  104.7370898 ,  108.43659687,
#         112.26677735,  116.23224687,  120.33778408,  124.58833643,
#         128.98902613,  133.54515629,  138.26221738,  143.14589375,
#         148.20207058,  153.43684089,  158.85651294,  164.4676178 ,
#         170.27691722,  176.29141181,  182.51834943,  188.96523397,
#         195.63983435,  202.55019392,  209.70464013,  217.11179457,
#         224.78058335,  232.7202479 ,  240.94035602,  249.45081352,
#         258.26187607,  267.38416158,  276.82866304,  286.60676169,
#         296.73024082,  307.21129989,  318.06256928,  329.29712551,
#         340.92850697,  352.97073027,  365.4383071 ,  378.34626171,
#         391.71014908,  405.54607358,  419.87070844,  434.70131581,
#         450.05576757,  465.95256687,  482.41087042,  499.45051159,
#         517.09202429,  535.35666774,  554.26645207,  573.84416483,
#         594.1133985 ,  615.09857886,  636.82499447,  659.31882713,
#         682.60718343,  706.71812739,  731.68071434,  757.52502588,
#         784.28220613,  811.98449932,  840.66528856,  870.35913615,
#         901.10182517,  932.93040263,  965.88322412, 1000.        ])

# %% [markdown]
# $\underline{\textbf{Q3.}}$ Display the original signal $\bar{x}$ as a function of T

# %%
plt.plot(np.log(T),signal)

# %% [markdown]
# $\underline{\textbf{Q4.}}$  Create t using a regular sampling strategy

# %%
M = 50 
t_min = 0
t_max = 1.5
t = np.array([t_min + ((m-1)/(M-1))*(t_max - t_min) for m in range(1,M+1)],dtype=np.float64)
t
# Out:
# array([0.        , 0.03061224, 0.06122449, 0.09183673, 0.12244898,
#        0.15306122, 0.18367347, 0.21428571, 0.24489796, 0.2755102 ,
#        0.30612245, 0.33673469, 0.36734694, 0.39795918, 0.42857143,
#        0.45918367, 0.48979592, 0.52040816, 0.55102041, 0.58163265,
#        0.6122449 , 0.64285714, 0.67346939, 0.70408163, 0.73469388,
#        0.76530612, 0.79591837, 0.82653061, 0.85714286, 0.8877551 ,
#        0.91836735, 0.94897959, 0.97959184, 1.01020408, 1.04081633,
#        1.07142857, 1.10204082, 1.13265306, 1.16326531, 1.19387755,
#        1.2244898 , 1.25510204, 1.28571429, 1.31632653, 1.34693878,
#        1.37755102, 1.40816327, 1.43877551, 1.46938776, 1.5       ])

# %% [markdown]
#  $\underline{\textbf{Q4.}}$ Construct matrix K using (3)

# %%
##### I should change this (no loop) ###########

K = np.zeros((M,N))

for n in range(N):
    for m in range(M):
        K[m,n] = np.exp(- t[m]*T[n])

# %% [markdown]
# $\underline{\textbf{Q5.}}$ Simulate the noisy data according to model (2), by taking $w \sim \mathcal{N} (0, \sigma^2 I_{M})$ with $\sigma = 0.01z^{(1)}$ , where $z = K\bar{x}$

# %%
x = signal
xmin = min(x)
xmax = max(x)
z = np.dot(K,x)
sigma = 0.01*z[0]
mean = np.zeros(M)
cov  = (sigma**2)*np.eye(M)

w = np.random.multivariate_normal(mean, cov)
y = z + w

# %% [markdown]
# $\underline{\textbf{Q6.}}$ Display the resulting noisy data y as a function of t

# %%
plt.plot(t,y)

# %% [markdown]
# ## 2) Comparison of regularization strategies

# %% [markdown]
# ###  Smoothness prior

# %% [markdown]
# Defintion of D

# %%
D = np.eye(N)

for n in range(N-1):
    D[n+1,n] = -1

D[0,N-1] = -1

# %% [markdown]
# $\underline{\textbf{Q3.}}$ Solving the optimization problem

# %%
beta = 1
x_hat = np.dot(np.linalg.inv(np.dot(K.T,K) + beta*np.dot(D.T,D)),np.dot(K.T,y))

# %%
def normalized_MSE(x,y):
    return( (np.linalg.norm(x-y)/np.linalg.norm(y))**2)

# %%
print(normalized_MSE(x_hat,x))
plt.plot(np.log(T),x_hat)
plt.plot(np.log(T),x)
plt.grid()
# Out:
# 189.27639781374333

# %% [markdown]
# $\underline{\textbf{Q4.}}$ Tunning $\beta$ with a grid search

# %%
beta_grid = np.exp(np.log(10)*np.linspace(-2,2,5))
errors = np.zeros(beta_grid.shape[0])

for i in range(beta_grid.shape[0]):
    beta = beta_grid[i]
    x_hat = np.dot(np.linalg.inv(np.dot(K.T,K) + beta*np.dot(D.T,D)),np.dot(K.T,y))
    errors[i] = normalized_MSE(x_hat,x)
    print("MSE : {}, beta : {}".format(normalized_MSE(x_hat,x),beta))
    plt.plot(np.log(T),x_hat)
    plt.plot(np.log(T),x)
    plt.grid()
    plt.show()
# Out:
# MSE : 1.5325397724193488, beta : 0.009999999999999995
# MSE : 0.21877164380163533, beta : 0.09999999999999998
# MSE : 0.34141894720625043, beta : 1.0
# MSE : 0.43137284226180017, beta : 10.000000000000002
# MSE : 0.47911304553834577, beta : 100.00000000000004

# %% [markdown]
# ### Smoothness prior + constraints

# %%
beta_grid = np.exp(np.log(10)*np.linspace(-4,2,7))

def proximal_gradient_smooth_cons(lamb,K,y,T,xmin,xmax,display = False):
    tol = 1e-7
    max_iter = 1000
    nb_iter = 0
    m = K.shape[0]
    n = K.shape[1]
    u = np.zeros((n,1))
    w,v = np.linalg.eig(np.dot(K.T,K) + lamb * np.dot(D.T,D))
    L = max(w)
    epsilon = 1/L
    norm2 = np.linalg.norm(np.dot(K,u) - y.reshape(m,1))
    normD = np.linalg.norm(np.dot(D,u))
    obj = 0.5 * norm2 **2 + 0.5 * lamb * normD ** 2 + ind(u,xmin,xmax)
    last_obj = 0
    if display:
        print("Objectif : {}, ||Ku-y||^2 : {}, ||Du||^2 : {}, ind : {}".format(obj,norm2**2,normD**2,ind(u,xmin,xmax)))
    
    while (abs(obj - last_obj) > tol and nb_iter < max_iter):
        w = u - epsilon * (np.dot(K.T,np.dot(K,u) - y.reshape(m,1)) + lamb * np.dot(D.T,np.dot(D,u)))
        last_obj = obj
        u = prox_cons(w,xmin,xmax) 
        norm2 = np.linalg.norm(np.dot(K,u) - y.reshape(m,1))
        normD = np.linalg.norm(np.dot(D,u))
        obj = 0.5 * norm2 **2 + 0.5*lamb * normD ** 2 + ind(u,xmin,xmax)
        if display:
            print("Objectif : {}, ||Ku-y||^2 : {}, ||Du||^2 : {}, ind : {}".format(obj,norm2**2,normD**2,ind(u,xmin,xmax)))
        nb_iter += 1
        
    return u
        
def prox_cons(w,xmin,xmax):
    m = w.shape[0]
    out = np.zeros((m,1))
    for index in range(m):
        value = w[index,0]
        if value >  xmax:
            out[index,0] = xmax
        elif value <  xmin:
            out[index,0] = xmin
        elif value >= xmin and value <= xmax:
            out[index,0] = value
    return out

def ind(x,xmin,xmax):
    n = x.shape[0]
    for i in range(n):
        if x[i] > xmax or x[i] < xmin:
            return 1e30
    return 0

for i in range(beta_grid.shape[0]):
    beta = beta_grid[i]
    x_hat = proximal_gradient_smooth_cons(beta,K,y,T,xmin,xmax) #,True
    print("MSE : {}, beta : {}\n".format(normalized_MSE(x_hat,x.reshape(200,1)),beta))
    plt.plot(np.log(T),x_hat)
    plt.plot(np.log(T),x)
    plt.grid()
    plt.show()
# Out:
# MSE : 0.3965980278049756, beta : 9.999999999999991e-05
# MSE : 0.39659884791111416, beta : 0.0009999999999999994
# MSE : 0.3966071163032604, beta : 0.009999999999999995
# MSE : 0.3966945197447686, beta : 0.09999999999999998
# MSE : 0.39763027629408426, beta : 1.0
# MSE : 0.40704349196799194, beta : 10.000000000000002
# MSE : 0.4969809240214601, beta : 100.00000000000004

# %% [markdown]
# ### Sparsity

# %%
beta_grid = np.exp(np.log(10)*np.linspace(-4,1,6))

def proximal_gradient_norme1(lamb,K,y,T,display = False):
    tol = 1e-7
    max_iter = 1000
    nb_iter = 0
    m = K.shape[0]
    n = K.shape[1]
    w,v = np.linalg.eig(np.dot(K.T,K))
    epsilon = 1/np.real(np.max(w))
    u = np.zeros((n,1))
    norm2 = np.linalg.norm(np.dot(K,u) - y.reshape(m,1))
    norm1 = np.linalg.norm(u,1)
    obj = 0.5*norm2**2 + lamb * norm1
    last_obj = 0
    if display:
        print("Objectif : {}, ||Ku-y||^2 : {}, ||u|| : {}".format(obj,norm2**2,norm1))
    
    while abs(obj - last_obj) > tol and nb_iter < max_iter:
        w = u - epsilon * np.dot(K.T,(np.dot(K,u) - y.reshape(m,1)))
        last_obj = obj
        u = prox_norme1(w,lamb,epsilon) 
        norm2 = np.linalg.norm(np.dot(K,u) - y.reshape(m,1))
        norm1 = np.linalg.norm(u,1)
        obj = 0.5*norm2**2 + lamb * norm1
        if display:
            print("Objectif : {}, ||Ku-y||^2 : {}, ||u|| : {}".format(obj,norm2**2,norm1))
        nb_iter += 1
    
    return u
        
def prox_norme1(w,lamb,epsilon):
    n = w.shape[0]
    out = np.zeros((n,1))
    for index in range(n):
        value = w[index,0]
        if value >  epsilon * lamb :
            out[index,0] = value - epsilon * lamb
        elif value <  -epsilon * lamb :
            out[index,0] = value + epsilon * lamb 
        elif value >=  -epsilon * lamb and value <= epsilon * lamb:
            out[index,0] = 0
    return out

for i in range(beta_grid.shape[0]):
    beta = beta_grid[i]
    x_hat = proximal_gradient_norme1(beta,K,y,T)
    print("MSE : {}, beta : {}".format(normalized_MSE(x_hat,x.reshape(200,1)),beta))
    plt.plot(np.log(T),x_hat)
    plt.plot(np.log(T),x)
    plt.grid()
    plt.show()
# Out:
# MSE : 0.43466709844904655, beta : 9.999999999999991e-05
# MSE : 0.42444040714948267, beta : 0.0009999999999999994
# MSE : 0.39607167776474206, beta : 0.009999999999999995
# MSE : 0.39603431045963355, beta : 0.09999999999999998
# MSE : 0.6857426492568485, beta : 1.0
# MSE : 1.0, beta : 10.000000000000002

# %% [markdown]
# ## Part 2

# %% [markdown]
# We define first the Lambert W-function, it well be usful to wright the proximity operator of the function **ent**

# %%
def W_exp(u):
    m = u.shape[0]
    output = np.zeros((m,1))
    
    for index in range(m):
        val = u[index,0]
    
        if val >= 100:
            output[index,0] = val - np.log(val)
    
        if val < 100 and val > - 20 :
            w = 1
            v = 0
            while abs(w - v)/abs(w) > 1.e-3:
                v = w
                e = np.exp(w)
                f = w*e - val
                w = w - f/((e*(w+1) - (w+2)*f/(2*w+2)))
            output[index,0] = w
            
        if val <=-20:
            output[index,0] = 0
        
    return output

# %%
beta_grid = np.exp(np.log(10)*np.linspace(-2,2,7))

def proximal_gradient_entr(lamb,K,y,T,xmin,xmax,display = False):
    tol = 1e-7
    max_iter = 1000
    nb_iter = 0
    m = K.shape[0]
    n = K.shape[1]
    u = np.zeros((n,1))
    for i in range(n):
        u[i,0] = random.random()
    w,v = np.linalg.eig(np.dot(K.T,K))
    epsilon = 1/np.real(np.max(w))
    norm2 = np.linalg.norm(np.dot(K,u) - y.reshape(m,1))
    ent = sum(np.multiply(u,np.log(u)))[0]
    obj = 0.5 * norm2 **2 + lamb * ent
    last_obj = 0
    if display:
        print("Objectif : {}, ||Ku-y||^2 : {}, ent : {}".format(obj,norm2**2,ent))
    
    while (abs(obj - last_obj) > tol and nb_iter < max_iter):
        w = u - epsilon * np.dot(K.T,np.dot(K,u) - y.reshape(m,1)) 
        last_obj = obj
        u = prox_entr(w,lamb,epsilon)
        
        #print(u)
        norm2 = np.linalg.norm(np.dot(K,u) - y.reshape(m,1))
        #ent = sum(np.multiply(u,np.log(u)))[0]
        obj = 0.5 * norm2 **2 + lamb * ent
        if display:
            print("Objectif : {}, ||Ku-y||^2 : {}, ent : {}".format(obj,norm2**2,ent))
        nb_iter += 1
        
    return u
        
def prox_entr(w,lamb,epsilon):    
    #return lamb*epsilon*W(np.power(np.exp(w- lamb * epsilon * (1+np.log(lamb*epsilon))*np.ones(w.shape)),1/(lamb*epsilon)))
    return lamb*epsilon*W(np.power(np.exp(w - lamb * epsilon * (1+np.log(lamb*epsilon))*np.ones(w.shape)),1/(lamb*epsilon)))

for i in range(beta_grid.shape[0]):
    beta = beta_grid[i]
    x_hat = proximal_gradient_entr(beta,K,y,T,xmin,xmax,True) #,True
    print("MSE : {}, beta : {}\n".format(normalized_MSE(x_hat,x.reshape(200,1)),beta))
    plt.plot(np.log(T),x_hat)
    plt.plot(np.log(T),x)
    plt.grid()
    plt.show()
# Out:
# Objectif : 7485.172761841736, ||Ku-y||^2 : 14971.36158058155, ent : -50.802844903855544
# Objectif : nan, ||Ku-y||^2 : nan, ent : -50.802844903855544
# MSE : nan, beta : 0.009999999999999995
# /home/maximilien/.local/lib/python3.6/site-packages/ipykernel_launcher.py:38: RuntimeWarning: overflow encountered in power
# /home/maximilien/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.
# /home/maximilien/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in double_scalars
#   from ipykernel import kernelapp as app
# /home/maximilien/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in double_scalars
#   from ipykernel import kernelapp as app
# Objectif : 8785.70402884678, ||Ku-y||^2 : 17575.855993906593, ent : -47.91394038203282
# Objectif : nan, ||Ku-y||^2 : nan, ent : -47.91394038203282
# MSE : nan, beta : 0.04641588833612775
# Objectif : 9050.004341385822, ||Ku-y||^2 : 18120.85838811208, ent : -48.38787974614454
# Objectif : nan, ||Ku-y||^2 : nan, ent : -48.38787974614454
# MSE : nan, beta : 0.21544346900318828
# Objectif : 10268.90893090033, ||Ku-y||^2 : 20635.638995231697, ent : -48.91056671551818
# Objectif : inf, ||Ku-y||^2 : inf, ent : -48.91056671551818
# Objectif : nan, ||Ku-y||^2 : nan, ent : -48.91056671551818
# MSE : nan, beta : 1.0
# /home/maximilien/.local/lib/python3.6/site-packages/ipykernel_launcher.py:38: RuntimeWarning: overflow encountered in exp
# Objectif : 6810.981959698813, ||Ku-y||^2 : 14090.80717888231, ent : -50.504609121071304
# Objectif : 5.1531130091347485e+70, ||Ku-y||^2 : 1.0306226018269497e+71, ent : -50.504609121071304
# Objectif : nan, ||Ku-y||^2 : nan, ent : -50.504609121071304
# MSE : nan, beta : 4.6415888336127775
# Objectif : 7149.1904102297785, ||Ku-y||^2 : 16489.327900739623, ent : -50.847377514322396
# Objectif : 1855127344169426.0, ||Ku-y||^2 : 3710254688341043.0, ent : -50.847377514322396
# Objectif : nan, ||Ku-y||^2 : nan, ent : -50.847377514322396
# MSE : nan, beta : 21.544346900318825
# Objectif : 1538.3989022468804, ||Ku-y||^2 : 13617.497013474962, ent : -52.70349604490598
# Objectif : -3562.5836645590243, ||Ku-y||^2 : 3415.5318798631524, ent : -52.70349604490598
# Objectif : -3953.6632189943007, ||Ku-y||^2 : 2633.3727709925997, ent : -52.70349604490598
# Objectif : -4082.028612029497, ||Ku-y||^2 : 2376.6419849222075, ent : -52.70349604490598
# Objectif : -4130.975475077297, ||Ku-y||^2 : 2278.7482588266075, ent : -52.70349604490598
# Objectif : -4150.267822300117, ||Ku-y||^2 : 2240.163564380967, ent : -52.70349604490598
# Objectif : -4157.9724310879865, ||Ku-y||^2 : 2224.7543468052277, ent : -52.70349604490598
# Objectif : -4161.071018385338, ||Ku-y||^2 : 2218.557172210525, ent : -52.70349604490598
# Objectif : -4162.324025882609, ||Ku-y||^2 : 2216.0511572159826, ent : -52.70349604490598
# Objectif : -4162.833731055432, ||Ku-y||^2 : 2215.0317468703383, ent : -52.70349604490598
# Objectif : -4163.042533754855, ||Ku-y||^2 : 2214.614141471491, ent : -52.70349604490598
# Objectif : -4163.128764774763, ||Ku-y||^2 : 2214.4416794316758, ent : -52.70349604490598
# Objectif : -4163.164691923535, ||Ku-y||^2 : 2214.3698251341293, ent : -52.70349604490598
# Objectif : -4163.179798470139, ||Ku-y||^2 : 2214.3396120409243, ent : -52.70349604490598
# Objectif : -4163.1862087609015, ||Ku-y||^2 : 2214.326791459398, ent : -52.70349604490598
# Objectif : -4163.188952886485, ||Ku-y||^2 : 2214.321303208231, ent : -52.70349604490598
# Objectif : -4163.190137210751, ||Ku-y||^2 : 2214.318934559699, ent : -52.70349604490598
# Objectif : -4163.1906520992425, ||Ku-y||^2 : 2214.317904782716, ent : -52.70349604490598
# Objectif : -4163.190877366547, ||Ku-y||^2 : 2214.317454248107, ent : -52.70349604490598
# Objectif : -4163.190976435968, ||Ku-y||^2 : 2214.3172561092647, ent : -52.70349604490598
# Objectif : -4163.191020179019, ||Ku-y||^2 : 2214.317168623163, ent : -52.70349604490598
# Objectif : -4163.19103954493, ||Ku-y||^2 : 2214.31712989134, ent : -52.70349604490598
# Objectif : -4163.191048129367, ||Ku-y||^2 : 2214.3171127224664, ent : -52.70349604490598
# Objectif : -4163.1910519335015, ||Ku-y||^2 : 2214.317105114199, ent : -52.70349604490598
# Objectif : -4163.191053615814, ||Ku-y||^2 : 2214.3171017495742, ent : -52.70349604490598
# Objectif : -4163.191054356732, ||Ku-y||^2 : 2214.317100267738, ent : -52.70349604490598
# Objectif : -4163.191054680885, ||Ku-y||^2 : 2214.317099619431, ent : -52.70349604490598
# Objectif : -4163.191054821308, ||Ku-y||^2 : 2214.317099338585, ent : -52.70349604490598
# Objectif : -4163.191054881272, ||Ku-y||^2 : 2214.3170992186574, ent : -52.70349604490598
# MSE : 440.7940314408803, beta : 100.00000000000004

# %% [markdown]
# **Douglas Rashford Algorithm**

# %% [markdown]
# We define $f(x) = \frac{1}{2}\left\|Kx-y\right\|^{2} $ and $g(x) = \beta .\text{ent}(x) = \beta.\sum_{i=1}^{N}\phi(x^{(n)})$. To implement the Rashford-Douglas algorithm we need to compute $prox_{\gamma f}$ and $prox_{\gamma g}$:
#
# $$prox_{\gamma f}(x) = (Id + \gamma K^{*}K)^{-1}(x+K^{*}y)$$
#
# $$prox_{\gamma g}(x)  = \left( prox_{\gamma \beta \phi}\left (x^{(n)}\right)\right)_{n=1,..,N}$$
#
# Where $prox_{\gamma \beta \phi}\left( x\right) =\beta \gamma W(e^{\frac{x}{\beta \gamma}-1 -ln(\beta \gamma)})$

# %%
def prox_gamma_f(x, K, y, gamma = 1):
    n = x.shape[0]
    return np.linalg.solve(np.eye(n) + gamma*np.dot(K.T,K), x + np.dot(K.T,y).reshape(-1,1))

def prox_gamma_g(x, gamma = 1):
    return gamma*W_exp((x/gamma)-1-np.log(gamma))
    

# We choose lambda = 1/it
def douglas_rashford(beta, K, y, x_init, gamma = 1, eps = 1e-3 , Iter_lim = 1000):
    it = 0
    x = x_init
    n = x.shape[0]
    matrix_temp = np.linalg.inv(np.eye(n) + gamma*np.dot(K.T,K))
    while (it < Iter_lim):
        it += 1
        #y_ = prox_gamma_g(x, gamma=gamma*beta)
        #z = prox_gamma_f(2*y_-x, K=K, y=y, gamma=gamma)
        y_ = beta*gamma*W_exp(x/(gamma*beta)-1-np.log(*beta*gamma))
        z = np.dot(matrix_temp, 2*y_- x + np.dot(K.T,y).reshape(-1,1))
        x = x + (1/it)*(z-y_)
    
    return z

# %%
beta_grid = np.exp(np.log(10)*np.linspace(-2,2,7))

for i in range(beta_grid.shape[0]):
    beta = beta_grid[i]
    x_init = np.ones((K.shape[1],1))
    x_hat = douglas_rashford(beta = beta,K=K,y=y,x_init = x_init) #,True
    print("MSE : {}, beta : {}\n".format(normalized_MSE(x_hat,x.reshape(200,1)),beta))
    plt.plot(np.log(T),x_hat)
    plt.plot(np.log(T),x)
    plt.grid()
    plt.show()
# Out:
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [ True]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# C:\Users\Othmane\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in double_scalars
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# MSE : nan, beta : 0.009999999999999995
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# MSE : 0.6301929685959318, beta : 0.04641588833612775
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# MSE : 0.47944280701915915, beta : 0.21544346900318828
# C:\Users\Othmane\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars
#
# C:\Users\Othmane\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in double_scalars
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# MSE : 0.8934862623539621, beta : 1.0
# [ True]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# MSE : nan, beta : 4.6415888336127775
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [ True]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# MSE : nan, beta : 21.544346900318825
# [ True]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# MSE : nan, beta : 100.00000000000004

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-c33d2c3179dd> in <module>()
# ----> 1 matrix_temp
#
# NameError: name 'matrix_temp' is not defined
